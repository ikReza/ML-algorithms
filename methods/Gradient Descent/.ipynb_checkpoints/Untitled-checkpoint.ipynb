# %% [markdown]
# # Gradient Descent
# 👉 It is an optimization algorithm that's used when training a machine learning model.
#
# 👉 It is an iterative algorithm, that starts from a random point on a function and travels down its slope in steps until
# - it reaches the lowest point of that function
# - or, it finished doing the defined number of steps

# %% [markdown]
# reference videos: [video 1](https://youtu.be/sDv4f4s2SB8 "StatQuest with Josh Starmer"), [video 2](https://youtu.be/vsWrXfO3wWw "codebasics")

# %% [markdown]
# The steps associated with gradient descent:
# 1. Find the slope of the objective function wrt each parameter/feature. In other words, compute the gradient of the function.
# 2. Pick a random initial value for the parameters.
# 3. Update the gradient function by plugging in the parameter values.
# 4. Calculate the step sizes for each feature as: $ stepSize = gradient * learningRate $
# 5. Calculate the new parameters as: $ newParams = oldParams - stepSize $
# 6. repeat 3 to 5 until the gradient is close to 0

# %% [markdown]
# ### What we learn from high school?
# Straight line equation: $ y = mx + b $, where
# - `m` is the slope of the line
# - `b` is the y intercept

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
plt.style.use("default")

# %%
plt.figure(figsize=(5, 3))
height = np.array([1.4, 1.9, 3.2])
weight = np.array([0.5, 2.3, 2.9])
ax = sns.scatterplot(x=weight, y=height)
ax.set(xlabel="weight", ylabel="height");

# %% [markdown]
# We have 3 datapoints. Let's try to draw a best fit line from our perspective.
#
# Take $m$ and $b$ value randomly. $ w = 0.65 $, $ b = 0 $

# %%
# solpe and y-intercept initialization
w = 0.65
b = 0

#x and y value initialization
x = [0, 0.5, 2.3, 2.9, 4]
y = [(w*val + b) for val in x]

plt.figure(figsize=(6, 3))
ax = sns.scatterplot(x=weight, y=height)
sns.lineplot(x, y, color="tomato")
ax.set(xlabel="weight", ylabel="height", xlim=(0,4), ylim=(0, 4));

# %% [markdown]
# ## Find actual best fit line
#
# We can get the actual best fit line using `scikit-learn`

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
regr.fit(weight.reshape(-1,1), height.reshape(-1,1))
slope = regr.coef_
yIntercept = regr.intercept_
y_pred = regr.predict(weight.reshape(-1,1))

# %%
print(f"m: {slope[0][0]:0.2f}, b: {yIntercept[0]:0.2f}")
# Out:
# m: 0.64, b: 0.95

# %%
df = pd.DataFrame()
df["weight"] = weight
df["height"] = height
df["predicted_height"] = y_pred
df
# Out:
#    weight  height  predicted_height
# 0     0.5     1.4          1.269231
# 1     2.3     1.9          2.423077
# 2     2.9     3.2          2.807692

# %%
# solpe and y-intercept initialization
w = 0.65
b = 0

#x and y value initialization
x = [0, 0.5, 2.3, 2.9, 4]
y = [(w*val + b) for val in x]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

ax1.scatter(weight, height, s=80)
ax1.plot(x, y, color="tomato")
ax1.set(xlabel="weight", ylabel="height", xlim=(0,4), ylim=(0, 4))
ax1.set(title="Assumed best fit line")

# solpe and y-intercept initialization
w = slope[0][0]
b = yIntercept[0]

#x and y value initialization
x = [0, 0.5, 2.3, 2.9, 4]
y = [(w*val + b) for val in x]

ax2.scatter(weight, height, s=80)
ax2.plot(x, y, color="green")
ax2.set(xlabel="weight", ylabel="height", xlim=(0,4), ylim=(0, 4))
ax2.set(title="Actual best fit line");

# %% [markdown]
# ### Make our assumed line a best fit line

# %%
# solpe and y-intercept initialization
w = 0.65
b = 0

#x and y value initialization
x = [0, 0.5, 2.3, 2.9, 4]
y = [(w*val + b) for val in x]

plt.figure(figsize=(6, 3))
ax = sns.scatterplot(x=weight, y=height, s=80)
sns.lineplot(x, y, color="red")
ax.set(xlabel="weight", ylabel="height", xlim=(0,4), ylim=(0, 4))

# draw lines
xx = [0.5, 2.3, 2.9]
y1 = [1.4, 1.9, 3.2]
y2 = [(w*val + b) for val in xx]

for i in range(3):
    value_1 = [xx[i], xx[i]]
    value_2 = [y1[i], y2[i]]
    plt.plot(value_1, value_2, c="green", linestyle='dashed', alpha=0.5);

# %% [markdown]
# #### Find the residuals
#
# $ residual = observedValue - predictedValue $, the green dashed lines in the above graph are the residuals. We need to find the sum of these residuals

# %% [markdown]
# $ mse = \frac{1}{n} \sum \limits _{i=1}^n (residual_i)^2 $
#
# ![image.png](attachment:image.png)
# Here, n = 3

# %%
mse = []

# %%
w, b = 0.65, 0

xx = [0.5, 2.3, 2.9]
y1 = [1.4, 1.9, 3.2]
y2 = [(w*val + b) for val in xx]

# find residuals
sum_residuals = 0

for i in range(3):
    res = y2[i] - y1[i]
    print(f"residual-{i+1} = {res:0.3f}")
    sum_residuals += res**2

mse1 = sum_residuals/3
mse.append(mse1)
print(f"mse = {sum_residuals/3}")
# Out:
# residual-1 = -1.075
# residual-2 = -0.405
# residual-3 = -1.315
# mse = 1.0162916666666668

# %% [markdown]
# ### Create a function to find `mse`

# %%
def find_mse(b):
    xx = [0.5, 2.3, 2.9]
    y1 = [1.4, 1.9, 3.2]
    y2 = [(w*val + b) for val in xx]

    # find residuals
    sum_residuals = 0

    for i in range(3):
        res = y2[i] - y1[i]
        print(f"residual-{i+1} = {res:0.3f}")
        sum_residuals += res**2

    error = sum_residuals/3
    print(f"mse for b = {b} is {error}")
    return error

# %% [markdown]
# ### Try for `y-intercept = 0.25`

# %%
mse2 = find_mse(0.25)
# Out:
# residual-1 = -0.825
# residual-2 = -0.155
# residual-3 = -1.065
# mse for b = 0.25 is 0.6129583333333336

# %%
mse.append(mse2)

# %% [markdown]
# ### Try for `y-intercept = 0.50`

# %%
mse3 = find_mse(0.5)
# Out:
# residual-1 = -0.575
# residual-2 = 0.095
# residual-3 = -0.815
# mse for b = 0.5 is 0.3346250000000002

# %%
mse.append(mse3)

# %% [markdown]
# ### Try for `y-intercept = 0.75`

# %%
mse4 = find_mse(0.75)
# Out:
# residual-1 = -0.325
# residual-2 = 0.345
# residual-3 = -0.565
# mse for b = 0.75 is 0.18129166666666685

# %%
mse.append(mse4)

# %% [markdown]
# ### Try for `y-intercept = 1.00`

# %%
mse5 = find_mse(1)
# Out:
# residual-1 = -0.075
# residual-2 = 0.595
# residual-3 = -0.315
# mse for b = 1 is 0.1529583333333335

# %%
mse.append(mse5)

# %% [markdown]
# ### Try for `y-intercept = 1.25`

# %%
mse6 = find_mse(1.25)
# Out:
# residual-1 = 0.175
# residual-2 = 0.845
# residual-3 = -0.065
# mse for b = 1.25 is 0.24962500000000012

# %%
mse.append(mse6)

# %% [markdown]
# ### Try for `y-intercept = 1.50`

# %%
mse7 = find_mse(1.5)
# Out:
# residual-1 = 0.425
# residual-2 = 1.095
# residual-3 = 0.185
# mse for b = 1.5 is 0.47129166666666683

# %%
mse.append(mse7)

# %% [markdown]
# #### observation
#
# from `mse6` the value of mse started increasing, so we found our desired mse in the previous value = `mse5`

# %% [markdown]
# ### plot the `mse` values

# %%
value_b = [0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5]

plt.figure(figsize=(10, 5))
plt.plot(value_b, mse, "o-", c='blue', markerfacecolor='red', markeredgecolor='k')
plt.xlabel("y-intercept")
plt.ylabel("mse")
plt.title("change of mse value wrt y-intercept")
plt.grid();

# %% [markdown]
# So we found the lowest point, when `y_intercept = 1.0` which is close to `0.95` that we got from `sklearn`'s `LiearRegression` model.
#
# However, there is a possibility that this point is not the actual minimum point. Because we didn't calculate for values between `0.75 & 1.0` and values between `1.0 & 1.25`

# %% [markdown]
# ### Is `Gradient Descent` good?
#
# As se have to calculate for so many values, obviously it'll take more time for calculation.
# - We assumed `w = 0.65` at the begining, but we also have to find this value using gradient descent
# - We have to calculate for every relevant feature

# %% [markdown]
# #### Good news! !!
#
# Gradient descend doesn't take value uniformly. It does less calculation at the points that are far from the optimal value by taking `big steps` and increase calculation when getting closer to the optimal solution by taking `baby steps`

# %% [markdown]
# ```py
# value_b = [0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5]
# ```
# Here, b value is increasing 0.25 every time.

# %% [markdown]
# ### Derivative/Gradient of MSE
#
# $ mse = \frac{1}{n} \sum \limits _{i=1}^n (y_i - \hat{y_i})^2 $ where $ \hat{y_i} = mx_i + b $
#
# ![two](images/two.png)
#
# Now, we'll do partial derivative w.r.t. `m` and `b`
#
# $ f(m, b) = \frac{1}{n} \sum \limits _{i=1}^n (y_i - (mx_i + b))^2 $
#
# ![three](images/three.png)

# %% [markdown]
# ##### w.r.t `m`
#
# $ \frac{\partial{f}}{\partial{m}} = \frac{1}{n} \sum \limits _{i=1}^n 2(y_i - (mx_i + b))*(0-x_i+0) $
#
# $ \frac{\partial{f}}{\partial{m}} = \frac{1}{n} \sum \limits _{i=1}^n -2x_i(y_i - (mx_i + b)) $
#
# $ \frac{\partial{f}}{\partial{m}} = \frac{-2}{n} \sum \limits _{i=1}^n x_i(y_i - (mx_i + b)) $
#
# ![four](images/four.png)

# %% [markdown]
# ##### w.r.t `b`
#
# $ \frac{\partial{f}}{\partial{b}} = \frac{1}{n} \sum \limits _{i=1}^n 2(y_i - (mx_i + b))*(0-(0+1)) $
#
# $ \frac{\partial{f}}{\partial{b}} = \frac{1}{n} \sum \limits _{i=1}^n -2(y_i - (mx_i + b)) $
#
# $ \frac{\partial{f}}{\partial{b}} = \frac{-2}{n} \sum \limits _{i=1}^n (y_i - (mx_i + b)) $
#
# ![five](images/five.png)

# %% [markdown]
# ### update `w` and `b`
#
# $ w = w - \mu \frac{\partial{f}}{\partial{m}} $ where $ \mu = learningRate $
#
# $ b = b - \mu \frac{\partial{f}}{\partial{b}} $
#
# This equations come from above mentioned pseudocode:
# - $ newParams = oldParams - stepSize $
# - $ stepSize = gradient * learningRate $

# %% [markdown]
# #### Derivatives
#
# $ \frac{\partial{f}}{\partial{m}} = \frac{-2}{n} \sum \limits _{i=1}^n x_i(y_i - (mx_i + b)) $
#
# $ \frac{\partial{f}}{\partial{b}} = \frac{-2}{n} \sum \limits _{i=1}^n (y_i - (mx_i + b)) $
#
# ![six](images/six.png)

# %%
def gradient_descent(x, y, epochs=10, lr=0.01):
    m_curr, b_curr = 0, 0
    n = len(x)
    val_m, val_b, mse = [], [], []
    
    for epoch in range(epochs):
        # y = mx + b
        y_pred = m_curr*x + b
        # cost/loss function (MSE)
        cost = (1/n) * sum(val**2 for val in (y-y_pred))
        val_m.append(m_curr)
        val_b.append(b_curr)
        mse.append(cost)
        # derivatives
        m_der = (-2/n) * sum(x*(y-y_pred))
        b_der = (-2/n) * sum(y-y_pred)
        # update m and b
        m_curr -= lr * m_der
        b_curr -= lr * b_der
        
        print(f"iteration: {epoch} => m: {m_curr}, b: {b_curr}, mse: {cost}")
    return val_m, val_b, mse

# %%
x = np.array([0.5, 2.3, 2.9])
y = np.array([1.4, 1.9, 3.2])

val = gradient_descent(x, y, epochs=70)
# Out:
# iteration: 0 => m: 0.09566666666666665, b: 0.04333333333333333, mse: 5.2700000000000005
# iteration: 1 => m: 0.1824363333333333, b: 0.08303133333333333, mse: 4.397346205555555
# iteration: 2 => m: 0.261136421, b: 0.11943208599999999, mse: 3.6794584342096286
# iteration: 3 => m: 0.3325174005136667, b: 0.15284223533533334, mse: 3.0888887769996716
# iteration: 4 => m: 0.39725994893256233, b: 0.18353990744914733, mse: 2.603057239065558
# iteration: 5 => m: 0.4559814403485007, b: 0.2117773627230433, mse: 2.203388410215598
# iteration: 6 => m: 0.5092418330627568, b: 0.23778340132313358, mse: 1.8746012478310075
# iteration: 7 => m: 0.5575490092545872, b: 0.26176554500008214, mse: 1.6041248174824858
# iteration: 8 => m: 0.6013636180605773, b: 0.28391201598174115, mse: 1.3816176525327049
# iteration: 9 => m: 0.6411034682476102, b: 0.30439353182877255, mse: 1.1985723557939325
# iteration: 10 => m: 0.6771475123672491, b: 0.3233649333686967, mse: 1.0479903254770786
# iteration: 11 => m: 0.7098394603837617, b: 0.3409666612320746, mse: 0.9241141688189487
# iteration: 12 => m: 0.7394910572347385, b: 0.35732609507082497, mse: 0.8222075724202949
# iteration: 13 => m: 0.7663850555785745, b: 0.3725587682292382, mse: 0.7383742127995387
# iteration: 14 => m: 0.7907779120764338, b: 0.3867694694505857, mse: 0.6694087833408833
# iteration: 15 => m: 0.8129022329199921, b: 0.4000532421250146, mse: 0.6126744417621495
# iteration: 16 => m: 0.8329689919250994, b: 0.41249629060738824, mse: 0.5660019923967462
# iteration: 17 => m: 0.8511695423427319, b: 0.4241768022475678, mse: 0.5276069485987467
# iteration: 18 => m: 0.8676774415715245, b: 0.43516569297187735, mse: 0.49602130421336577
# iteration: 19 => m: 0.8826501061720394, b: 0.44552728352549276, mse: 0.4700374054453767
# iteration: 20 => m: 0.8962303129647065, b: 0.4553199128242886, mse: 0.4486617771077891
# iteration: 21 => m: 0.9085475605256554, b: 0.4645964942649631, mse: 0.43107713783150114
# iteration: 22 => m: 0.9197193040634362, b: 0.4734050202983215, mse: 0.4166111519155021
# iteration: 23 => m: 0.9298520754522033, b: 0.4817890200772442, mse: 0.4047107230676915
# iteration: 24 => m: 0.939042499101815, b: 0.48978797454339384, mse: 0.3949208471764689
# iteration: 25 => m: 0.9473782133520129, b: 0.4974376929108582, mse: 0.3868672155644305
# iteration: 26 => m: 0.9549387061769423, b: 0.5047706541368151, mse: 0.38024190357241877
# iteration: 27 => m: 0.9617960731691534, b: 0.5118163166354246, mse: 0.37479159728750233
# iteration: 28 => m: 0.9680157050310888, b: 0.5186013991883301, mse: 0.3703079082725219
# iteration: 29 => m: 0.9736569111298642, b: 0.5251501357304821, mse: 0.36661940598803744
# iteration: 30 => m: 0.9787734850614535, b: 0.5314845064408806, mse: 0.3635850632722087
# iteration: 31 => m: 0.983414217617405, b: 0.5376244473418788, mse: 0.36108886427137465
# iteration: 32 => m: 0.987623362045653, b: 0.5435880404057507, mse: 0.35903536865953767
# iteration: 33 => m: 0.991441056042074, b: 0.5493916859813492, mse: 0.3573460625479555
# iteration: 34 => m: 0.9949037044968277, b: 0.5550502591850838, mse: 0.35595635656456853
# iteration: 35 => m: 0.9980443266452894, b: 0.5605772517475377, mse: 0.35481311632704127
# iteration: 36 => m: 1.0008928709339442, b: 0.56598490066835, mse: 0.35387263088887977
# iteration: 37 => m: 1.003476500603754, b: 0.5712843049061935, mse: 0.35309894148366167
# iteration: 38 => m: 1.0058198527142717, b: 0.5764855312165842, mse: 0.3524624666681483
# iteration: 39 => m: 1.007945273078511, b: 0.5815977101467752, mse: 0.3519388712976411
# iteration: 40 => m: 1.0098730293488762, b: 0.5866291231031251, mse: 0.3515081360896886
# iteration: 41 => m: 1.0116215042860974, b: 0.5915872813212011, mse: 0.3511537922016018
# iteration: 42 => m: 1.0132073710541571, b: 0.5964789974916627, mse: 0.3508622915564111
# iteration: 43 => m: 1.0146457522127872, b: 0.601310450724938, mse: 0.35062248884214553
# iteration: 44 => m: 1.0159503639236647, b: 0.6060872454741855, mse: 0.3504252153790577
# iteration: 45 => m: 1.0171336467454306, b: 0.6108144649784195, mse: 0.350262928561922
# iteration: 46 => m: 1.0182068842647722, b: 0.6154967197354265, mse: 0.35012942347409204
# iteration: 47 => m: 1.0191803106948152, b: 0.6201381914666985, mse: 0.35001959564709395
# iteration: 48 => m: 1.020063208466864, b: 0.6247426729936288, mse: 0.3499292458950417
# iteration: 49 => m: 1.0208639967461122, b: 0.6293136044052213, mse: 0.3498549197618657
# iteration: 50 => m: 1.0215903117153904, b: 0.6338541058622024, mse: 0.3497937754427346
# iteration: 51 => m: 1.0222490793925259, b: 0.6383670073503509, mse: 0.3497434751297458
# iteration: 52 => m: 1.0228465816756875, b: 0.6428548756667682, mse: 0.3497020956275657
# iteration: 53 => m: 1.0233885162465153, b: 0.6473200388964254, mse: 0.34966805482147684
# iteration: 54 => m: 1.023880050902256, b: 0.6517646086123912, mse: 0.3496400511863887
# iteration: 55 => m: 1.0243258728350129, b: 0.6561905000114387, mse: 0.349617014023987
# iteration: 56 => m: 1.0247302333280233, b: 0.6605994501770416, mse: 0.3495980625253744
# iteration: 57 => m: 1.0250969882951837, b: 0.66499303464391, mse: 0.3495824720939923
# iteration: 58 => m: 1.0254296350503982, b: 0.6693726824220264, mse: 0.34956964664120627
# iteration: 59 => m: 1.0257313456573778, b: 0.6737396896234447, mse: 0.34955909579529726
# iteration: 60 => m: 1.0260049971779084, b: 0.6780952318217977, mse: 0.34955041615246096
# iteration: 61 => m: 1.0262531991070296, b: 0.6824403752623704, mse: 0.3495432758529614
# iteration: 62 => m: 1.0264783182567425, b: 0.6867760870296367, mse: 0.3495374018927184
# iteration: 63 => m: 1.026682501325532, b: 0.6911032442692138, mse: 0.3495325696851984
# iteration: 64 => m: 1.0268676953689242, b: 0.6954226425521769, mse: 0.34952859447451434
# iteration: 65 => m: 1.027035666366281, b: 0.6997350034614911, mse: 0.34952532427142036
# iteration: 66 => m: 1.0271880160608835, b: 0.7040409814729057, mse: 0.34952263404211514
# iteration: 67 => m: 1.027326197233888, b: 0.7083411701959255, mse: 0.34952042092766766
# iteration: 68 => m: 1.0274515275578031, b: 0.712636108034371, mse: 0.34951860031128035
# iteration: 69 => m: 1.0275652021615942, b: 0.7169262833205079, mse: 0.34951710258303

# %%
# val[0,1, 2] = [m, b, mse]
plt.figure(figsize=(20, 9))
plt.plot(val[0], val[2], "p-", c='green', markerfacecolor='yellow', markeredgecolor='k', label="m", ms=10)
plt.plot(val[1], val[2], "o-", c='blue', markerfacecolor='red', markeredgecolor='k', label="b", ms=8)
plt.ylabel("mse")
plt.title("change of mse value w.r.t m and b")
plt.legend()
plt.grid();

# %% [markdown]
# # epochs and learning rate
#
# Selection of `epoch number` and `learning rate` is a trial and error process.

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
# %matplotlib notebook

plt.figure(figsize=(10, 7))
ax = plt.axes(projection="3d")
xline = [i for i in range(70)] #epochs
yline = val[0] #m
zline = val[2] #mse
ax.plot3D(xline, yline, zline, "blue")
ax.scatter3D(xline, yline, zline, c="red")
ax.set(xlabel="nos. of epoch", ylabel="value of m", zlabel="mse");
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook

plt.figure(figsize=(10, 7))
ax = plt.axes(projection="3d")
xline = [i for i in range(70)] #epochs
yline = val[1] #b
zline = val[2] #mse
ax.plot3D(xline, yline, zline, "green")
ax.scatter3D(xline, yline, zline, c="red")
ax.set(xlabel="nos. of epoch", ylabel="value of b", zlabel="mse");
# Out:
# <img src="data:image/png;base64,..." width="1000">
